# %%
# Import dependencies

import json #for extracting the wiki json
import pandas as pd # to create dataframes
import numpy as np #for converting data types
import re

from sqlalchemy import create_engine
from config import db_password
import time

# %%
# varible that holds file directory

file_dir = 'C://Users/njliv/Class_Work/Movies-ETL/Module/'

# %%
#open file 

f'{file_dir}wikipedia-movies.json'
# Out:
# 'C://Users/njliv/Class_Work/Movies-ETL/Module/wikipedia-movies.json'

# %%
#using the with statement open up JSON file to read 'r' and as file

with open (f'{file_dir}JSON/wikipedia-movies.json', mode = 'r')as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# to see the First 5 records

wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
# Last 5 records

wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
# ...

# %%
# Some records in the middle

wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
#8.3.3 Investigating the Wiki Data

# %%
wiki_movie_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movie_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# Well have to convert the df columns to a list inoder to view them all
wiki_movie_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
# Save filter expression into an intermediate variable

# %%
wiki_movies= [movie for movie in wiki_movies_raw 
              if ('Director' in movie or 'Directed by' in movie)
              and 'imdb_link' in movie]

# %%
len(wiki_movies)
# Out:
# 7080

# %%
wiki_movies_df= pd.DataFrame(wiki_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Adaptation by',
#  'Suggested by',
#  'Traditional',
#  'Mandarin',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
# ...

# %%
wiki_movies_df = [movie for movie in wiki_movies_raw 
              if ('Director' in movie or 'Directed by' in movie)
              and 'imdb_link' in movie
              and 'No. of episodes' not in movie]

# %%
wiki_movies_df= pd.DataFrame(wiki_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
#8.3.4 Revisit Functions

# %%
square = lambda x: x*x

# %%
square(70)
# Out:
# 4900

# %%
#8.3.5 Create a Funtion to Clean the Data Part 1

# %%
def clean_movie(movie):
    
    #movie_copy = dict(movie) #movie is the parameter and dict() is the constructor
    
    movie = dict(movie) #create a non destructive copy (movie variable is local)
    
    return movie # the clean_movie function refers to the the local variable and will only affect the 'copy'

# %%
# Lets revert to back to the df and look at he language.

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6838  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7062   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6838  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7062  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6838  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7062                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6838                                                NaN
# 7062  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6838                                                NaN      NaN
# 7062  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 6838    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7062     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
#8.3.5 Skill Drill

# %%
#sorted(wiki_movies_df.columns.tolist())

# %%
#Make a list out of the wiki columns

wi = wiki_movies_df.columns

# %%
#Cheack for alternate title data

wiki_movies_df[wiki_movies_df['Cantonese'].notnull()]
# Out:
#                                          url  year  \
# 6460  https://en.wikipedia.org/wiki/Ip_Man_3  2016
#
#                                   imdb_link     title Directed by  \
# 6460  https://www.imdb.com/title/tt2888046/  Ip Man 3  Wilson Yip
#
#        Produced by Screenplay by Story by Based on  \
# 6460  Raymond Wong           NaN      NaN      NaN
#
#                                                Starring  ... Hepburn  \
# 6460  [Donnie Yen, Zhang Jin, Lynn Hung, Patrick Tam...  ...     NaN
#
#      Literally                  Cantonese Chinese Yiddish Arabic Romanized  \
# 6460       NaN  [Jip, 6, Man, 6, Saam, 1]     NaN     NaN    NaN       NaN
#
#      Russian Hebrew Polish
# 6460     NaN    NaN    NaN
#
# [1 rows x 78 columns]

# %%
#Cheack for alternate title data

wiki_movies_df[wiki_movies_df['Chinese'].notnull()]
# Out:
#                                          url  year  \
# 6624  https://en.wikipedia.org/wiki/Rock_Dog  2017
#
#                                   imdb_link     title  Directed by  \
# 6624  https://www.imdb.com/title/tt2822672/  Rock Dog  Ash Brannon
#
#                                             Produced by  \
# 6624  [Amber Wang, David B. Miller, Rob Feng, Joyce ...
#
#                     Screenplay by                  Story by  \
# 6624  [Ash Brannon, Kurt Voelker]  [Ash Brannon, Zheng Jun]
#
#                               Based on  \
# 6624  [Tibetan Rock Dog, by Zheng Jun]
#
#                                                Starring  ... Hepburn  \
# 6624  [Luke Wilson, Eddie Izzard, J. K. Simmons, Lew...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 6624       NaN       NaN    摇滚藏獒     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 6624    NaN
#
# [1 rows x 78 columns]

# %%
#Cheack for alternate title data
#the value_counts() method is a quick, easy way to see what non-null values there are in a column.

wiki_movies_df['Revised Romanization'].value_counts()
# Out:
# Wondeopul deijeu    1
# Pai seutori         1
# Name: Revised Romanization, dtype: int64

# %%
#Same value_counts() method

wiki_movies_df['Revised Romanization'].notnull().value_counts()
# Out:
# False    7078
# True        2
# Name: Revised Romanization, dtype: int64

# %%
#Create Df to view all columns

df_1= pd.DataFrame(wiki_movies_df[wiki_movies_df[wi].notnull()['title']])
#print(df_1[wi].info())

# %%
#Create Df to view all columns
df= pd.DataFrame(wiki_movies_df[wiki_movies_df[wi].notnull()['url']])
#df.head()
print(df[wi].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7080 entries, 0 to 7079
# Data columns (total 78 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   url                     7080 non-null   object
#  1   year                    7080 non-null   int64
#  2   imdb_link               7080 non-null   object
#  3   title                   7079 non-null   object
#  4   Directed by             7078 non-null   object
#  5   Produced by             6716 non-null   object
#  6   Screenplay by           2319 non-null   object
#  7   Story by                1002 non-null   object
#  8   Based on                2191 non-null   object
#  9   Starring                6895 non-null   object
#  10  Narrated by             283 non-null    object
#  11  Music by                6482 non-null   object
#  12  Cinematography          6380 non-null   object
#  13  Edited by               6379 non-null   object
# ...

# %%
#Create Df to view all columns
#df_3= pd.DataFrame(wiki_movies_df[wiki_movies_df[wi].notnull()['url']])
#df.head()
#print(df_3[wi].info())

# %%
#Function Building Continued

# %%
def clean_movie(movie):
    
    movie = dict(movie) #create a non-destructive copy
    
    alt_titles = {}
    
    #COMBINE  ALT Titles into one list
    
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        
        if key in movie:
            
            alt_titles[key] = movie[key]
            
            movie.pop(key)
            
    if len('alt_titles') > 0:
        
        movie['alt_titles'] = alt_titles
        
   


    return movie

# %%
#After adding in merged column names re run list comp

clean_movies = [clean_movie(movie) for movie in wiki_movies]

wiki_movies_df = pd.DataFrame(clean_movies)

sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'No. of episodes',
#  'Opening theme',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
# ...

# %%
#Create Df to view all columns info
#w = wiki_movies_df.columns

#df_1= pd.DataFrame(wiki_movies_df[wiki_movies_df[w].notnull()['url']])
#print(df_1[w].info())

# %%
#8.3.6 Create a Function to Clean Data Part 2

# %%
def clean_movie(movie):
    
    movie = dict(movie) #create a non-destructive copy
    
    alt_titles = {}
    
    #COMBINE  ALT Titles into one list
    
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                
                'Mandarin','McCune–Reischauer','Original title','Polish',
                
                'Revised Romanization','Romanized','Russian',
                
                'Simplified','Traditional','Yiddish']:
        
        if key in movie:
            
            alt_titles[key] = movie[key]
            
            movie.pop(key)
            
    if len('alt_titles') > 0:
        
        movie['alt_titles'] = alt_titles
            
    #Combine the movie column names
    
    def change_column_name(old_name, new_name):
        
        if old_name in movie:
            
            movie[new_name] = movie.pop(old_name)
            
    change_column_name('Adaptation by', 'Writer(s)')
    
    change_column_name('Country of origin', 'Country')
    
    change_column_name('Directed by', 'Director')
    
    change_column_name('Distributed by', 'Distributor')
    
    change_column_name('Edited by', 'Editor(s)')
    
    change_column_name('Length', 'Running time')
    
    change_column_name('Original release', 'Release date')
    
    change_column_name('Music by', 'Composer(s)')
    
    change_column_name('Produced by', 'Producer(s)')
    
    change_column_name('Producer', 'Producer(s)')
    
    change_column_name('Productioncompanies ', 'Production company(s)')
    
    change_column_name('Productioncompany ', 'Production company(s)')
    
    change_column_name('Released', 'Release Date')
    
    change_column_name('Release Date', 'Release date')
    
    change_column_name('Screen story by', 'Writer(s)')
    
    change_column_name('Screenplay by', 'Writer(s)')
    
    change_column_name('Story by', 'Writer(s)')
    
    change_column_name('Theme music composer', 'Composer(s)')
    
    change_column_name('Written by', 'Writer(s)')
    

    return movie

# %%
#After adding in merged column names re run list comp

clean_movies = [clean_movie(movie) for movie in wiki_movies]

wiki_movies_df = pd.DataFrame(clean_movies)

sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Narrated by',
#  'No. of episodes',
#  'Opening theme',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
#To track why certain decisions were made, show the evolution of the function through multiple cells.

# %%
#8.3.7

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')

print(len(wiki_movies_df))
# Out:
# 7080

# %%
#Drop Duplicates

wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)

print(len(wiki_movies_df))

wiki_movies_df.head()
# Out:
# 7037
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# ...

# %%
#Skill Drill
#Create Df to view all null columns

w = wiki_movies_df.columns

df_2= pd.DataFrame(wiki_movies_df[wiki_movies_df[w].notnull()])

print(df_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7037 entries, 0 to 7079
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   url                     7037 non-null   object
#  1   year                    7037 non-null   int64
#  2   imdb_link               7037 non-null   object
#  3   title                   7036 non-null   object
#  4   Based on                2182 non-null   object
#  5   Starring                6852 non-null   object
#  6   Narrated by             282 non-null    object
#  7   Cinematography          6344 non-null   object
#  8   Release date            7005 non-null   object
#  9   Running time            6898 non-null   object
#  10  Country                 6801 non-null   object
#  11  Language                6789 non-null   object
#  12  Budget                  4739 non-null   object
#  13  Box office              5485 non-null   object
# ...

# %%
#As per 8.3.7
#null values for each column use a list comprehension

[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4855],
#  ['Starring', 185],
#  ['Narrated by', 6755],
#  ['Cinematography', 693],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 248],
#  ['Budget', 2298],
#  ['Box office', 1552],
#  ['alt_titles', 0],
#  ['Director', 0],
#  ['Distributor', 360],
#  ['Editor(s)', 548],
#  ['Composer(s)', 519],
#  ['Producer(s)', 203],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 201],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6937],
#  ['Production location(s)', 6987],
#  ['Picture format', 6969],
#  ['Audio format', 6973],
#  ['Voices of', 7035],
#  ['Followed by', 7028],
#  ['Created by', 7026],
#  ['Opening theme', 7036],
#  ['No. of episodes', 7033],
#  ['Preceded by', 7027],
#  ['Suggested by', 7036],
#  ['Recorded', 7035],
#  ['Venue', 7036],
#  ['Label', 7035],
#  ['Animation by', 7035],
# ...

# %%
#Let's make a list of columns that have less than 90% null values and use those to trim down our dataset.



wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum()
                        < len(wiki_movies_df) * 0.9]

#Modify the df to have the new list of columns

wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

print(wiki_movies_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7037 entries, 0 to 7079
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    7037 non-null   object
#  1   year                   7037 non-null   int64
#  2   imdb_link              7037 non-null   object
#  3   title                  7036 non-null   object
#  4   Based on               2182 non-null   object
#  5   Starring               6852 non-null   object
#  6   Cinematography         6344 non-null   object
#  7   Release date           7005 non-null   object
#  8   Running time           6898 non-null   object
#  9   Country                6801 non-null   object
#  10  Language               6789 non-null   object
#  11  Budget                 4739 non-null   object
#  12  Box office             5485 non-null   object
#  13  alt_titles             7037 non-null   object
# ...

# %%
# 1 Addiditonal column ? alt_columns?
# 4 addition entries?

# %%
#8.3.8 Make a plan to Convert and Parse the Data

# %%
#Inspect the data types
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# alt_titles               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
#Create a DATA series for the box office column

box_office = wiki_movies_df['Box office'].dropna()

#Habit Check, check len
len(box_office)
# Out:
# 5485

# %%
#Regular expressions only work on strings, so we'll need to make sure all of the box office data
#is entered as a string. By using the map() method, we can see which values are not strings.

# %%
#First, make a is_not_a_string() function:

def  is_not_a_string(x):
    
    return type(x) != str

box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 75                    [$6,488,144, (US), [1]]
# 127                [US$1,531,489, (domestic)]
# 131                          [US$, 4,803,039]
#                         ...
# 6984               [$99.6, million, [4], [5]]
# 6998                   [$365.6, million, [1]]
# 6999                         [$53.8, million]
# 7019                     [$435, million, [7]]
# 7052                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# Lets try lambda instead

box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 75                    [$6,488,144, (US), [1]]
# 127                [US$1,531,489, (domestic)]
# 131                          [US$, 4,803,039]
#                         ...
# 6984               [$99.6, million, [4], [5]]
# 6998                   [$365.6, million, [1]]
# 6999                         [$53.8, million]
# 7019                     [$435, million, [7]]
# 7052                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# Lets use the apply method and a ' ' to our joining characters and apply the join() function only when out
#DATA points are lists



box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7074       $19.4 million
# 7075       $41.9 million
# 7076       $76.1 million
# 7077       $38.4 million
# 7078        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# Lets import Pythons mod for regular expressions. Look to the the top for import re

box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7074       $19.4 million
# 7075       $41.9 million
# 7076       $76.1 million
# 7077       $38.4 million
# 7078        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# See the difference?

# %%
#8.3.9

# %%
#--

# %%
#8.3.10 Parse the Box office Data

# %%
# 1 dollar sign
# 2 abritrary (but not zero) # of digits
# 3 optional decimal point
# 4 arbitrart (but not zero) # of more digits
# 5 space maybe more
# 6 million billion

form_one = r'\$\d+\.?\d*\s*[mb]illion'

# %%
# Add in arguemnts to the and find total number that return true

box_office.str.contains(form_one, flags = re.IGNORECASE, na = False).sum()
b=box_office.str.contains(form_one, flags = re.IGNORECASE, na = False).sum()
print(f'There are {b} box office values that match the form "123.4 million/billion."')
# Out:
# There are 3896 box office values that match the form "123.4 million/billion."

# %%
#Create the Second Form

# %%
# 1 dollar sign 
# 2 add group of one to three
# 3 Match  <= 1  group starting with a comma and followed by exactly 3 digits

form_two = r'\$\d{1,3}(?:,\d{3})+'

# %%
# Count box office values equal to this form

box_office.str.contains(form_two, flags = re.IGNORECASE, na = False).sum()
b2=box_office.str.contains(form_two, flags = re.IGNORECASE, na = False).sum()
print(f'There are {b2} box office values that match the form "123,456,789."')
# Out:
# There are 1544 box office values that match the form "123,456,789."

# %%
# Create Boolean Series

matches_form_one = box_office.str.contains(form_one, flags = re.IGNORECASE, na = False)
matches_form_two = box_office.str.contains(form_two, flags = re.IGNORECASE, na = False)

# %%
# Use pandas element wise logic operators to find the remaining forms

box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 80                              $335.000
# 111                   $4.35-4.37 million
# 131                        US$ 4,803,039
# 602                           $5000 (US)
# 733                         $ 11,146,270
# 959                             $ 50,004
# 1072                          35,254,617
# 1150    $ 407,618 (U.S.) (sub-total) [1]
# 1449                        $ 11,829,959
# 1483                          £3 million
# 1614                            $520.000
# 1868                        ¥1.1 billion
# 2036                                 N/A
# 2095                                $309
# 2134               US$ 171.8 million [9]
# 2261                   US$ 3,395,581 [1]
# 2267            $ 1,223,034 ( domestic )
# 2351                            $282.175
# 2642            $ 104,883 (US sub-total)
# 2669         926,423 admissions (France)
# 2701      $ 1.7 million (US) (sub-total)
# 2827                            $414.000
# ...

# %%
#Fix Pattern Matches 

#spaces in between the dollar sign and the number 

form_one = r'\$\s*\d+\.?\d*\s*[mb]illion'

form_two = r'\$\s*\d{1,3}(?:,\d{3})+'

# %%
# period as a thousands separator, not a comma

form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+'

#add a negative lookahead group that looks ahead for "million" or "billion

form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

# %%
#Some values are given as a range.

box_office = box_office.str.replace(r'\$.*[---](?![a-z])', '$', regex=True)
# Out:
# C:\Users\njliv\anaconda3\envs\PythonData\lib\site-packages\pandas\core\strings\object_array.py:156: FutureWarning: Possible set difference at position 6
#   pat = re.compile(pat, flags=flags)

# %%
# Million is miss spelled so times

form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'

# %%
matches_form_one = box_office.str.contains(form_one, flags = re.IGNORECASE, na = False)
matches_form_two = box_office.str.contains(form_two, flags = re.IGNORECASE, na = False)

# %%
#Extract and Convert Box Office Values

# %%
def parse_dollars(s):
    
    
    #if s is not a string, return NaN
    
    if  type(s) != str:
        
        return np.nan
    
    
    #if input is of the form $###.# million
    
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags = re.IGNORECASE):   
        
        
        #remove dollar sign and 'million'
        
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        #Convert to float and multiply by a million
        
        value = float(s) * 10**6
        
        # return value
        
        return value
        
        
        
     #if input is of the form $###.# billion
    
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
    
    
        #remove dollar sign and 'million'
        
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        #Convert to float and multiply by a billion
        
        value = float(s) * 10**9
        
        # return value
        
        return value
    
    
    # if input is of the form $###,###,###
    
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags = re.IGNORECASE): 
    
    
    
        #Convert dollar sign and commas 
        
        s = re.sub('\$|,','', s)
        
        
        #convert to float
        
        value = float(s)
        
        
        # return to value
        
        return value
        
        
    #otherwise, return nan
    
    else:
        
        return np.nan
    

    
# Next, we'll use re.sub(pattern, replacement_string, string)
# to remove dollar signs, spaces, commas, and letters, if necessary.    
    
# Finally, convert all the strings to floats, multiply by the right amount, and return the value.

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)   
    
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7075    41900000.0
# 7076    76100000.0
# 7077    38400000.0
# 7078     5500000.0
# 7079           NaN
# Name: box_office, Length: 7037, dtype: float64

# %%
#We no longer need the Box Office column, so we'll just drop it:

wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
len(wiki_movies_df)
# Out:
# 7037

# %%
#8.3.11 Parse Budget Data

# %%
#Create a budget variable 

budget = wiki_movies_df['Budget'].dropna()

# %%
#Convert any lists to strings

budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
#remove any values between a dollar sign and a hyphen 

budget = budget.str.replace(r'\$.*[---](?![a-z)])','$', regex=True)

# %%
# Create Pattern Matches for budget

matches_form_one = budget.str.contains(form_one, flags = re.IGNORECASE, na = False)

matches_form_two = budget.str.contains(form_two, flags = re.IGNORECASE, na = False)

budget[~matches_form_one & ~matches_form_two]
# Out:
# 111                     $5–7 million
# 137                          Unknown
# 197     $6.5–10 million [1] [Note 1]
# 205      60 million Norwegian Kroner
# 236                   $50–65 million
#                     ...
# 7066                $100–150 million
# 7070                $160–200 million
# 7071                $102–135 million
# 7072                  $39–50 million
# 7074                    €4.3 million
# Name: Budget, Length: 230, dtype: object

# %%
#Remove the citation references with the following

budget = budget.str.replace(r'\[\d+\]\s*', '')

budget[~matches_form_one & ~matches_form_two]
# Out:
# C:\Users\njliv\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 111                    $5–7 million
# 137                         Unknown
# 197        $6.5–10 million [Note 1]
# 205     60 million Norwegian Kroner
# 236                  $50–65 million
#                    ...
# 7066               $100–150 million
# 7070               $160–200 million
# 7071               $102–135 million
# 7072                 $39–50 million
# 7074                   €4.3 million
# Name: Budget, Length: 230, dtype: object

# %%
#parse the budget values.

wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
#Parse the Release Dates

# %%
#variable that holds the non-null values of Release date in the DataFrame, converting lists to strings

release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
#The forms we'll be parsing are:

#Full month name, one- to two-digit day, four-digit year (i.e., January 1, 2000)

date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
#month, dd, yyyy

#Four-digit year, two-digit month, two-digit day, with any separator (i.e., 2000-01-01)

date_form_two = r'\d{4}.[01]\d.[0123]\d'
#yyyy-mm-dd and yyyy/mm/dd

#Full month name, four-digit year (i.e., January 2000)

date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
#month yyyy

#Four-digit year

date_form_four = r'\d{4}'
#yyyy

#onsider using the re.VERBOSE option

# %%
#extract the dates

release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7075  December 25, 2018
# 7076  December 11, 2018
# 7077   November 8, 2018
# 7078    August 31, 2018
# 7079      December 2018
#
# [7005 rows x 1 columns]

# %%
#Since there are different date formats,
#set the infer_datetime_format option to True

wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
#Parse the Runninh Time

# %%
# make a variable that holds the non-null values of Release date in the DataFrame, converting lists to strings

running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
#entries just look like "100 minutes

running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6531

# %%
#get a sense of what the other 366 entries look like

running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6504       114 minutes [1] 120 minutes (extended edition)
# 6647                                             104 mins
# 6713    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7061    108 minutes (Original cut) 98 minutes (UK cut)...
# 7079                Variable; 90 minutes for default path
# Name: Running time, Length: 367, dtype: object

# %%
#make this more general by only marking the beginning of the string,
#and accepting other abbreviations of "minutes" by only searching up to the letter "m."

running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6881

# %%
# Capture the remaining 

running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
# Out:
# 670                     UK:84 min (DVD version) US:86 min
# 729                         78-102 min (depending on cut)
# 842                       Varies (79 [3] –84 [1] minutes)
# 1350                                              25 : 03
# 1446    United States: 77 minutes Argentina: 94 minute...
# 1502                                            1hr 35min
# 1554                                               varies
# 1777                    Netherlands:96 min, Canada:95 min
# 1780                                       approx. 14 min
# 2277                                           1 h 43 min
# 2997                                               1h 48m
# 3929                                              4 hours
# 4429    US domestic version: 86 minutes Original versi...
# 4971    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5428                    115 [1] /123 [2] /128 [3] minutes
# 5451                                    1 hour 32 minutes
# ...

# %%
#We can match all of the hour + minute patterns with one regular expression pattern. Our pattern follows:

# 1 Start with one or more digits.

# 2 Have an optional space after the digit and before the letter "h."

# 3 Capture all the possible abbreviations of "hour(s)." To do this,
# 4 we'll make every letter in "hours" optional except the "h."
# 5 Have an optional space after the "hours" marker.
# 6 Have an optional number of digits for minutes.

#As a pattern, this looks like "\d+\s*ho?u?r?s?\s*\d*".

# %%
#Add a capture group around the \d to grab the digits

running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# %%
# Using to_numeric(), coerce, and fillna() convert the empty strings to numeric values, turn those into nan 
# and change the nan to a zero

running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
#apply a function that will convert the hour capture groups 
#minute capture groups to minutes if the pure minutes capture group is zero,
#save the output to wiki movies df

wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
#drop Running time from the dataset

wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %%
#Wikipedia dataset has been cleaned!

# %%
#8.3.12 Clean the Kaggle Data

# %%
# varible that holds file directory

file_dir = 'C://Users/njliv/Class_Work/Movies-ETL/Module/'

kaggle_metadata = pd.read_csv(f'{file_dir}Kaggle/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}Kaggle/ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
ratings.head()

# sample n=5 will show five random rows from the dataset

kaggle_metadata.sample(n=5)

kaggle_metadata['id']

ratings.tail()

#8.3.12 Clean the Kaggle Data

#Check the column dtypes

kaggle_metadata.dtypes

#Before we convert the "adult" and "video" columns
# Check if all are true or false

kaggle_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
#Remove the Bad data

kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]

#keep rows where the adult column is False, and then drop the adult column

kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

# look at the values of the video column

kaggle_metadata['video'].value_counts()

#Convert the Data Types

kaggle_metadata['video'] == 'True'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: video, Length: 45454, dtype: bool

# %%
# The above code creates the Boolean column we want.
#Assign it back to video

kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

#use the to_numeric() method from Pandas using 
#errors= argument is set to 'raise', 
#so we'll know if there's any data that can't be converted to numbers.

kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)

kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')

kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# convert release_date to datetime. 
#Using the Pandas datatime built in function

kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

# %%
#Reasonability Checks on Ratings Data

#use the info() method on the DataFrame. 
#Since the ratings dataset has so many rows,
#we need to set the null_counts option to True.

#kaggle_metadata.info(null_counts = True)

ratings.info(null_counts= True)
# Out:
# C:\Users\njliv\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: null_counts is deprecated. Use show_counts instead
#   if __name__ == '__main__':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
#We'll specify in to_datetime() that the origin is 'unix' and the time unit is seconds

pd.to_datetime(ratings['timestamp'], unit='s')
# Out:
# 0          2015-03-09 22:52:09
# 1          2015-03-09 23:07:15
# 2          2015-03-09 22:52:03
# 3          2015-03-09 22:52:26
# 4          2015-03-09 22:52:36
#                    ...
# 26024284   2009-10-31 23:26:04
# 26024285   2009-10-31 23:33:52
# 26024286   2009-10-31 23:29:24
# 26024287   2009-11-01 00:06:30
# 26024288   2009-10-31 23:30:58
# Name: timestamp, Length: 26024289, dtype: datetime64[ns]

# %%
# Since the output looks reasonable, assign it to the timestamp column.

ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# %%
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
#People are more likely to give whole number ratings than half, which explains the spikes in the histogram. 
#The median score is 3.5, the mean is 3.53, and all the ratings are between 0 and 5.

# %%
# 8.4.1 Merge the Wiki and Keggle Metadata

# %%
#Print out a list of the columns so we can identify which ones are redundant.
#We'll use the suffixes parameter to make it easier to identify which table each column came from

movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title_wiki',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Release date',
#  'Country',
#  'Language',
#  'alt_titles',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id',
#  'box_office',
#  'budget_wiki',
#  'release_date_wiki',
#  'running_time',
#  'belongs_to_collection',
#  'budget_kaggle',
#  'genres',
#  'homepage',
#  'id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date_kaggle',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title_kaggle',
#  'video',
#  'vote_average',
#  'vote_count']

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle
# running_time             runtime
# budget_wiki              budget_kaggle
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
#Time to compare

#take a quick look at some of the titles

movies_df[['title_wiki','title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6049                A Fantastic Woman                A Fantastic Woman
# 6050                       Permission                       Permission
# 6051                         Loveless                         Loveless
# 6052                           Gemini                           Gemini
# 6053  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6054 rows x 2 columns]

# %%
#Look at the rows where the titles don't match.

movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5958                                            Chips
# 5973                                            Spark
# 5996  Pirates of the Caribbean:Dead Men Tell No Tales
# 6025       Valerian and the Cityof a Thousand Planets
# 6030            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# ...

# %%
# Show any rows where title_kaggle is empty


movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Country, Language, alt_titles, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 45 columns]

# %%
#Runtime

#Use a scatter plot to see how similar the  rows are


movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')
# Out:
# <AxesSubplot:xlabel='running_time', ylabel='runtime'>

# %%
#Notice that there are more data points on the origin of the Y axis than on the origin
#of the X axis. Since the X axis is Wikipedia and the Y axis is Kaggle, this means there 
#are more missing entries in the Wikipedia data set than in the Kaggle data set

# %%
# Budget
#Since budget_wiki and budget_kaggle are numeric, we'll make another scatter plot

movies_df.fillna(0).plot(x='budget_wiki',y='budget_kaggle', kind='scatter')
# Out:
# <AxesSubplot:xlabel='budget_wiki', ylabel='budget_kaggle'>

# %%
# the wiki data may have more outliers but 
# the keggle has movies with no data
#there for well fill in the gaps with wiki data

# %%
#Box office
#Also numeric so make a scatter

movies_df.fillna(0).plot(x='box_office', y= 'revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
# Re adjust the scatter 

movies_df.fillna(0)[movies_df['box_office'] < 10**9].plot(x='box_office', y= 'revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
# looks similar to what we've seen for budget, so we'll make the same decision:
#keep the Kaggle data, but fill in the zeros with Wikipedia data.

# %%
#Release Date

# %%
#We'll use the regular line plot (which can plot date data),
#and change the style to only put dots by adding style='.' to the plot() method

movies_df[['release_date_wiki','release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')
# Out:
# <AxesSubplot:xlabel='release_date_wiki'>

# %%
#investigate that wild outlier around 2006.
#We'll look for any movie whose release date according to Wikipedia is after 1996,
#but whose release date according to Kaggle is before 1965.



movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]
# Out:
#                                             url  year  \
# 3609  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link   title_wiki Based on  \
# 3609  https://www.imdb.com/title/tt00457939/  The Holiday      NaN
#
#                                                Starring Cinematography  \
# 3609  [Kate Winslet, Cameron Diaz, Jude Law, Jack Bl...    Dean Cundey
#
#                               Release date        Country Language  ...  \
# 3609  [December 8, 2006, (, 2006-12-08, )]  United States  English  ...
#
#      release_date_kaggle              revenue              runtime  \
# 3609          1953-08-28        30,500,000.00               118.00
#
#                               spoken_languages    status  \
# 3609  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3609  Pouring out of impassioned pages...brawling th...
#
# ...

# %%
#looks like somehow The Holiday in the Wikipedia 
#data got merged with From Here to Eternity. 
#We'll have to drop that row from our DataFrame

#find the index of that movie

movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index
# Out:
# Int64Index([3609], dtype='int64')

# %%
#Now drop it

movies_df = movies_df.drop(movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index)

#cHECK FOR ANY NULL values

movies_df[movies_df['release_date_wiki'].isnull()]
# Out:
#                                                     url  year  \
# 1010  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1063    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1123  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1566  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1635      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1777        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2388  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2788   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3176  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3653  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4969  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# 1010  https://www.imdb.com/title/tt0112519/            Black Scorpion
# 1063  https://www.imdb.com/title/tt0113080/                     Flirt
# ...

# %%
# Wikipedia data is missing release dates for 11 movies

#Just Drop Wiki

# %%
#Language
# Well compare thte value counts of each

# %%
movies_df['Language'].value_counts()
# error because some of the language data points are stored as lists.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# English                        5479
# [English, Spanish]               68
# [English, French]                35
# [English, Japanese]              25
# [English, Russian]               23
#                                ...
# [English /, Zulu]                 1
# [English, Hebrew, Spanish]        1
# [English, Japanese, French]       1
# [English, Spanish, Apache]        1
# Russian                           1
# ...

# %%
movies_df['original_language'].value_counts()
# Out:
# en    5989
# fr      16
# es      10
# it       8
# de       6
# ja       4
# pt       4
# zh       4
# da       2
# hi       2
# sv       1
# ko       1
# ab       1
# tr       1
# he       1
# ar       1
# cn       1
# ru       1
# Name: original_language, dtype: int64

# %%
#cONVERT THE LANGUAGE'S TO tuples so that the  value_counts() 
#Method works 

movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna =False)
# Out:
# English                        5479
# NaN                             136
# (English, Spanish)               68
# (English, French)                35
# (English, Japanese)              25
#                                ...
# (English /, Zulu)                 1
# (English, Hebrew, Spanish)        1
# (English, Japanese, French)       1
# (English, Spanish, Apache)        1
# Russian                           1
# Name: Language, Length: 198, dtype: int64

# %%
#decisions that save time are usually the ones that win, so we'll use the Kaggle data here.

# %%
#Production Companies

# %%
#start off just taking a look at a small number of samples

movies_df[['Production company(s)','production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6049                           [Fabula, Komplizen Film]
# 6050                           Ball & Chain Productions
# 6051          [Arte France Cinéma, Why Not Productions]
# 6052  [Film Science, Rough House Pictures, Syncopate...
# 6053         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# ...

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle            Drop Wiki 
# running_time             runtime                 Keep Keggle; fill in zeros with wiki data
# budget_wiki              budget_kaggle           Keep Keggle; fill in zeros with wiki data  
# box_office               revenue                 Keep Keggle; fill in zeros with wiki data
# release_date_wiki        release_date_kaggle     Drop Wiki
# Language                 original_language       Drop Wiki
# Production company(s)    production_companies    Drop Wiki

# %%
#Put it all together

#drop the title_wiki, release_date_wiki, Language, and Production company(s) columns

movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)

# %%
#we'll make a function that fills in missing data
#for a column pair and then drops the redundant column.

def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
        , axis=1)
    
    df.drop(columns=wiki_column, inplace=True)

# %%
#run the function for the three column pairs that we decided to fill in zeros

fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')

fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')

fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')

movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6049    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6050    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6051      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6052   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6053  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link  \
# 0     https://www.imdb.com/title/tt0098987/
# 1     https://www.imdb.com/title/tt0098994/
# 2     https://www.imdb.com/title/tt0099005/
# ...

# %%
#Don't forget, we need to convert lists to tuples for value_counts() to work.
#Write for loop over columns

for col in movies_df.columns:
    
    lists_to_tuples = lambda x: tuple(x) if type(x) == list else x
    
    value_counts = movies_df[col].apply(lists_to_tuples).value_counts(dropna=False)
    
    num_values = len(value_counts)
    
    if num_values == 1:
        
        print(col)
# Out:
# video

# %%
#Drop video

movies_df['video'].value_counts(dropna=False)
# Out:
# False    6053
# Name: video, dtype: int64

# %%
#reorder the columns in groups:

#Identifying information (IDs, titles, URLs, etc.)
#Quantitative facts (runtime, budget, revenue, etc.)
#Qualitative facts (genres, languages, country, etc.)
#Business data (production companies, distributors, etc.)
#People (producers, director, cast, writers, etc.)

movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on'
                      ]]

# %%
# Rename the columns

movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

# %%
#  movies_df = movies_df[[‘imdb_id’, ‘title_kaggle’, … ]] anyother was to change column names
#May throw an error tho.

# %%
# 8.4.2 Transform and Merge Rating Data

# %%
#First, we need to use a groupby on the "movieId" and "rating" columns and take the count for each group.

rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count()

# %%
#The choice of renaming "userId" to "count" is arbitrary. 
#Both "userId" and "timestamp" have the same information, so we could use either one

rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1)

# %%
#Now the magical part.

# %%
# We can pivot this data so that movieId is the index
# the columns will be all the rating values, and the 
#rows will be the counts for each rating value.

rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1) \
                .pivot(index='movieId',columns='rating', values='count')

# %%
#We'll prepend rating_ to each column with a list comprehension:

rating_counts.columns = ['rating_' + str(col) for col in rating_counts.columns]

# %%
#left merge, since we want to keep everything in movies_df

movies_with_ratings_df = pd.merge(movies_df, rating_counts, left_on='kaggle_id', right_index=True, how='left')

# %%
# Finally Finally, because not every movie got a rating for each rating level
# there will be missing values instead of zeros.

movies_with_ratings_df[rating_counts.columns] = movies_with_ratings_df[rating_counts.columns].fillna(0)

# %%
#finished the Transform step in ETL!

# %%
#For our local server, the connection string will be as follows:

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_data"

# %%
#Create the database engine with the following line in a new cell:

engine = create_engine(db_string)

# %%
#Import the Movie Data

movies_df.to_sql(name = 'movies', con = engine)

# %%
# Do not run this yet!
# create a variable for the number of rows imported

#rows_imported = 0

#for data in pd.read_csv(f'{file_dir}ratings.csv', chunksize=1000000):

    # print out the range of rows that are being imported
    
    #print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    

    #data.to_sql(name='ratings', con=engine, if_exists='append')

    # increment the number of rows imported by the chunksize
    
    #rows_imported += len(data)

    # print that the rows have finished importing
    
    #print('Done.')

# %%
rows_imported = 0

# get the start_time from time.time()
start_time = time.time()


for data in pd.read_csv(f'{file_dir}Kaggle/ratings.csv', chunksize=1000000):

    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='ratings', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000000...Done. 45.6879358291626 total seconds elapsed
# importing rows 1000000 to 2000000...Done. 89.85397338867188 total seconds elapsed
# importing rows 2000000 to 3000000...Done. 131.64885878562927 total seconds elapsed
# importing rows 3000000 to 4000000...Done. 173.50150084495544 total seconds elapsed
# importing rows 4000000 to 5000000...Done. 214.22911143302917 total seconds elapsed
# importing rows 5000000 to 6000000...Done. 255.80227828025818 total seconds elapsed
# importing rows 6000000 to 7000000...Done. 301.64218258857727 total seconds elapsed
# importing rows 7000000 to 8000000...Done. 348.6601207256317 total seconds elapsed
# importing rows 8000000 to 9000000...Done. 393.58357191085815 total seconds elapsed
# importing rows 9000000 to 10000000...Done. 437.198970079422 total seconds elapsed
# importing rows 10000000 to 11000000...Done. 481.2893464565277 total seconds elapsed
# ...
